# %% [markdown]
# ## Frontier Model APIs

# %% [markdown]
# ## Lets connect Multiple frontier models together through their APIs

# %%
#imports 

import os
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display
import requests

# %%
load_dotenv(override = True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
grok_api_key = os.getenv('GROK_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')


if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

if grok_api_key:
    print(f"Grok API Key exists and begins {grok_api_key[:4]}")
else:
    print("Grok API Key not set (and this is optional)")

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:3]}")
else:
    print("OpenRouter API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key exists and begins sk-ant-
# Google API Key exists and begins AI
# DeepSeek API Key exists and begins sk-
# Groq API Key exists and begins gsk_
# Grok API Key exists and begins xai-
# OpenRouter API Key exists and begins sk-

# %%
# Connect with OpenAI Client Model
openai = OpenAI()


anthropic_url = "https://api.anthropic.com/v1/"
gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
deepseek_url = "https://api.deepseek.com"
groq_url = "https://api.groq.com/openai/v1"
grok_url = "https://api.x.ai/v1"
openrouter_url = "https://openrouter.ai/api/v1"
ollama_url = "http://localhost:11434/v1"

anthropic = OpenAI(api_key = anthropic_api_key, base_url=anthropic_url)
gemini = OpenAI(api_key = google_api_key, base_url=gemini_url)
deepseek = OpenAI(api_key=deepseek_api_key, base_url=deepseek_url)
groq = OpenAI(api_key = groq_api_key, base_url=grok_url)
grok = OpenAI(api_key=grok_api_key, base_url=grok_url)
openrouter = OpenAI(api_key=openrouter_api_key, base_url = openrouter_url)
ollama = OpenAI(api_key="ollama", base_url = ollama_url)

# %% [markdown]
# ### Now I am asking this question to all models to check their answers
#
# #### Q - If a rooster lays an egg on top of a slanted barn roof, which way does it roll?
# #### A - It doesn’t roll! Roosters don't lay eggs

# %%
puzzle = """
You and a partner are contestants on a game show. You're each taken to separate rooms and given a choice:
Cooperate: Choose "Share" — if both of you choose this, you each win $1,000.
Defect: Choose "Steal" — if one steals and the other shares, the stealer gets $2,000 and the sharer gets nothing.
If both steal, you both get nothing.
Do you choose to Steal or Share? Pick one.
"""

user_prompt = [{"role":"user", "content": puzzle}]

# %%
#gpt

response = openai.chat.completions.create(model = "gpt-5-nano", messages=user_prompt)
display(Markdown(response.choices[0].message.content))
# Out:
# Steal.
#
# Reason: If your partner shares, stealing yields $2,000 vs $1,000. If your partner steals, you get $0 either way. So stealing is the dominant (or weakly dominant) strategy, maximizing your own payoff in all cases.

# %%
response = anthropic.chat.completions.create(model = "claude-sonnet-4-5-20250929", messages=user_prompt)
display(Markdown(response.choices[0].message.content))
# Out:
# **Share**
#
# I would choose Share because:
#
# 1. **Mutual benefit**: If we both share, we both walk away with $1,000, which is a guaranteed positive outcome.
#
# 2. **Risk assessment**: While stealing could get me $2,000, it only works if my partner shares. If we both steal (which is likely if I'm thinking this way, they might be too), we both get nothing.
#
# 3. **Expected value**: Without knowing my partner, assuming roughly equal probability of their choices, sharing gives me a better expected outcome than the all-or-nothing gamble of stealing.
#
# The game show format suggests this is meant to be played once, not repeatedly, but the principle remains: cooperation yields a certain mutual gain, while defection risks everything for a chance at more.
#
# **My choice: Share**

# %%
response = deepseek.chat.completions.create(model = "deepseek-reasoner", messages=user_prompt)
display(Markdown(response.choices[0].message.content))
# Out:
# I choose to Steal. In this classic Prisoner's Dilemma, stealing is the dominant strategy: it guarantees a better or equal outcome regardless of the partner's choice. If they share, I get $2,000; if they also steal, I get $0 (same as if I had shared). While mutual cooperation would yield $1,000 each, the lack of trust and individual incentives make stealing the rational choice.

# %%
esponse = grok.chat.completions.create(model="grok-4", messages=user_prompt)
display(Markdown(response.choices[0].message.content))
# Out:
# I choose to Steal. In this classic Prisoner's Dilemma, stealing is the dominant strategy: it guarantees a better or equal outcome regardless of the partner's choice. If they share, I get $2,000; if they also steal, I get $0 (same as if I had shared). While mutual cooperation would yield $1,000 each, the lack of trust and individual incentives make stealing the rational choice.

# %%
requests.get("http://localhost:11434/").content
# Out:
# b'Ollama is running'

# %%
# !ollama pull llama3.2
# Out:
# ]11;?\pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=user_prompt)
display(Markdown(response.choices[0].message.content))
# Out:
# I would choose to Share.

# %% [markdown]
# ## Gemini and Anthropic Client Library

# %%
from google import genai

client = genai.Client()
response = client.models.generate_content(  
    model="gemini-2.5-flash-lite",  #
    contents="Describe the color Blue to someone who's never been able to see in 1 sentence"
)
print(response.text)
# Out:
# Blue is the feeling of a cool breeze on a clear summer day, like the vast, calm expanse above us.

# %%
from anthropic import Anthropic

client = Anthropic()

response = client.messages.create(
    model="claude-sonnet-4-5-20250929",
    messages=[{"role": "user", "content": "Describe the color Blue to someone who's never been able to see in 1 sentence"}],
    max_tokens=100)

print(response.content[0].text)
# Out:
# Blue is the calm, cool feeling of a gentle breeze on your skin, the peaceful quiet of early morning, and the refreshing chill of water washing over you.

# %% [markdown]
# ### Routers
# #### A router decides which model or tool to send a request to based on some logic.
#
#
# ###### ONE API key, ONE SDK, ONE format
# ###### client = openai.OpenAI(base_url="https://openrouter.ai/api/v1", api_key="or-key")
#
# ###### client.chat.completions.create(model="openai/gpt-4o", ...)
# ###### client.chat.completions.create(model="anthropic/claude-3-5-sonnet", ...)
# ###### client.chat.completions.create(model="google/gemini-flash", ...)

# %%
response = openrouter.chat.completions.create(model="z-ai/glm-4.5", messages=user_prompt)
display(Markdown(response.choices[0].message.content))
# Out:
# ---------------------------------------------------------------------------
# APIStatusError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 response = openrouter.chat.completions.create(model="z-ai/glm-4.5", messages=user_prompt)
#       2 display(Markdown(response.choices[0].message.content))
#
# File ~/AI-Projects/dev_Ai/.venv/lib/python3.13/site-packages/openai/_utils/_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# ## LiteLLM

# %%
from litellm import completion

response = completion(model = "openai/gpt-4.1", messages = user_prompt)
reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# Given just this information, and assuming I care about maximizing my own payout (as a rational agent), I would **choose "Steal"**.
#
# Here's the reasoning (the classic "Prisoner's Dilemma" logic):
#
# - If my partner chooses "Share":
#    - If I choose "Steal", I get $2,000 (best possible for me).
#    - If I choose "Share", I get $1,000.
#
# - If my partner chooses "Steal":
#    - If I choose "Steal", I get $0.
#    - If I choose "Share", I get $0.
#
# No matter what my partner does, I never come out worse by stealing—and sometimes come out better.
# So strictly maximizing a single round's payout: **I choose "Steal."**
#
# Of course, if this is an iterated game or trust matters, I might reconsider!
# But with these one-shot rules, "Steal" is the game-theoretic answer.

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 106
# Output tokens: 204
# Total tokens: 310
# Total cost: 0.1844 cents
