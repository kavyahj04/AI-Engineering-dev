# %%
import tiktoken

encoding = tiktoken.encoding_for_model("gpt-4.1-mini")
tokens = encoding.encode("Hi My name is Kavya")

# %%
tokens
# Out:
# [12194, 3673, 1308, 382, 138762, 2090]

# %%
for tokenid in tokens:
    decode_text = encoding.decode([tokenid])
    print(f"{tokenid} = {decode_text}")
# Out:
# 12194 = Hi
# 3673 =  My
# 1308 =  name
# 382 =  is
# 138762 =  Kav
# 2090 = ya
